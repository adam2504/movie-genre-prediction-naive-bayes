# %%
import pandas as pd

df = pd.read_csv("hf://datasets/HenryWaltson/TMDB-IMDB-Movies-Dataset/TMDB  IMDB Movies Dataset.csv")

df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords          directors  \
# 0  rescue, mission, dream, airplane, paris, franc...  Christopher Nolan
# 1  rescue, future, spacecraft, race against time,...  Christopher Nolan
# 2  joker, sadism, chaos, secret identity, crime f...  Christopher Nolan
# 3  future, society, culture clash, space travel, ...      James Cameron
# 4  new york city, superhero, shield, based on com...        Joss Whedon
#
#                                              writers averageRating numVotes  \
# 0                                  Christopher Nolan           8.8  2770171
# 1                  Jonathan Nolan, Christopher Nolan           8.7  2456592
# 2  Jonathan Nolan, Christopher Nolan, David S. Go...           9.1  3116358
# 3                                      James Cameron           7.9  1472421
# 4                              Joss Whedon, Zak Penn           8.0  1539740
#
#                                                 cast
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 1  Matthew McConaughey, Anne Hathaway, Michael Ca...
# 2  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 3  Sam Worthington, Zoe Saldaña, Sigourney Weaver...
# 4  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Exploration du Dataset ##

# %% [markdown]
# The Dataset was found on [HuggingFace](https://huggingface.co/datasets/HenryWaltson/TMDB-IMDB-Movies-Dataset).
# It is composed of TMDB and IMDB movies data.

# %%
print(f"The dataset contains {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# The dataset contains 434803 rows and 29 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434803 entries, 0 to 434802
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    434803 non-null  int64
#  1   title                 434803 non-null  object
#  2   vote_average          434803 non-null  float64
#  3   vote_count            434803 non-null  int64
#  4   status                434803 non-null  object
#  5   release_date          414261 non-null  object
#  6   revenue               434803 non-null  int64
#  7   runtime               434803 non-null  int64
#  8   adult                 434803 non-null  bool
#  9   backdrop_path         184870 non-null  object
#  10  budget                434803 non-null  int64
#  11  homepage              54526 non-null   object
#  12  tconst                434803 non-null  object
#  13  original_language     434803 non-null  object
#  14  original_title        434803 non-null  object
#  15  overview              392288 non-null  object
#  16  popularity            434803 non-null  float64
#  17  poster_path           359619 non-null  object
#  18  tagline               91750 non-null   object
#  19  genres                355967 non-null  object
#  20  production_companies  261479 non-null  object
#  21  production_countries  320339 non-null  object
#  22  spoken_languages      331531 non-null  object
#  23  keywords              170484 non-null  object
#  24  directors             424832 non-null  object
#  25  writers               369685 non-null  object
#  26  averageRating         434803 non-null  float64
#  27  numVotes              434803 non-null  int64
#  28  cast                  366256 non-null  object
# dtypes: bool(1), float64(3), int64(6), object(19)
# memory usage: 93.3+ MB

# %% [markdown]
# ### Nettoyage des données

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Feature Engineering

# %%
# Feature 1: Rating combiné pondéré
# Utiliser numVotes comme poids (IMDB a plus de votes donc plus fiable)
total_votes = df['vote_count'] + df['numVotes']
combined_rating = (df['vote_average'] * df['vote_count'] + df['averageRating'] * df['numVotes']) / total_votes

df['rating'] = combined_rating

# Feature 2: Total des votes (log scale pour éviter les outliers)
total_vote_count = np.log1p(df['vote_count'] + df['numVotes'])  # log1p pour éviter log(0)

df['total_votes'] = total_vote_count

# %% [markdown]
# ### Focus on the Genres

# %%
unique_genres = df['genres'].dropna().str.split(', ').explode().unique()
number_of_genre = len(unique_genres)

print(f"There is {number_of_genre} different genres, that are :", sorted(unique_genres))
# Out:
# There is 19 different genres, that are : ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction', 'TV Movie', 'Thriller', 'War', 'Western']

# %%
single_genre_count = df[df['genres'].str.contains(',', na=True) == False].shape[0]
print(f"Number of rows with only one unique genre: {single_genre_count}")
# Out:
# Number of rows with only one unique genre: 187825

# %%
df[df['genres'].str.contains(',', na=True) == False]
# Out:
#             id                        title  vote_average  vote_count  \
# 7          550                   Fight Club         8.438       27238
# 95       18785                 The Hangover         7.312       15812
# 216         14              American Beauty         8.000       11260
# 218      37799           The Social Network         7.358       11190
# 221        489            Good Will Hunting         8.149       11111
# ...        ...                          ...           ...         ...
# 434781  836515                Наши знакомые         0.000           0
# 434784  836522              Они живут рядом         0.000           0
# 434786  836534                   The Picnic         0.000           0
# 434790  836378  Guns N Roses: Live Rarities         0.000           0
# 434801  836333         The Vampire Assassin         0.000           0
#
#           status release_date    revenue  runtime  adult  \
# 7       Released   1999-10-15  100853753      139  False
# 95      Released   2009-06-02  469310836      100  False
# 216     Released   1999-09-15  356296601      122  False
# 218     Released   2010-10-01  224920315      121  False
# 221     Released   1997-12-05  225933435      127  False
# ...          ...          ...        ...      ...    ...
# 434781  Released   1969-06-02          0        0  False
# 434784  Released   1968-05-06          0        0  False
# 434786  Released   1998-10-03          0       17  False
# 434790  Released   2007-08-17          0       37  False
# 434801  Released   2007-04-15          0       19  False
#
#                            backdrop_path  ...       genres  \
# 7       /hZkgoQYus5vegHoetLkCJzb17zJ.jpg  ...        Drama
# 95      /2o0PKGmnSgCGkzoSePNAqse8Ure.jpg  ...       Comedy
# 216      /DztBnZaqmla2sGUW9s8AyOmskT.jpg  ...        Drama
# 218     /2BNKxbq4muNcwTjSDNCYnvr1dM8.jpg  ...        Drama
# 221     /bpV8wn48s82au37QyUJ51S7X2Vf.jpg  ...        Drama
# ...                                  ...  ...          ...
# 434781                               NaN  ...        Drama
# 434784                               NaN  ...        Drama
# 434786                               NaN  ...        Drama
# 434790                               NaN  ...  Documentary
# 434801                               NaN  ...       Horror
#
#                                      production_companies  \
# 7       Regency Enterprises, Fox 2000 Pictures, Taurus...
# 95      Legendary Pictures, Green Hat Films, Warner Br...
# 216              Jinks/Cohen Company, DreamWorks Pictures
# 218     Columbia Pictures, Relativity Media, Scott Rud...
# 221     Miramax, Lawrence Bender Productions, Be Gentl...
# ...                                                   ...
# 434781                                 Gorky Film Studios
# 434784                                            Mosfilm
# 434786                                                NaN
# 434790                            Shoreline Entertainment
# 434801                              ArchAngel Productions
#
#                      production_countries spoken_languages  \
# 7                United States of America          English
# 95      Germany, United States of America          English
# 216              United States of America          English
# 218              United States of America          English
# 221              United States of America          English
# ...                                   ...              ...
# 434781                       Soviet Union              NaN
# 434784                       Soviet Union              NaN
# 434786                        South Korea           Korean
# 434790                                NaN          English
# 434801           United States of America          English
#
#                                                  keywords        directors  \
# 7       dual identity, rage and hate, based on novel o...    David Fincher
# 95      blackjack, stag night, lost weekend, chapel, h...    Todd Phillips
# 216     estate agent, adultery, coming out, first time...       Sam Mendes
# 218     hacker, based on novel or book, boston, massac...    David Fincher
# 221     boston, massachusetts, professor, baseball, ma...     Gus Van Sant
# ...                                                   ...              ...
# 434781                                                NaN       Ilya Gurin
# 434784                                                NaN  Grigoriy Roshal
# 434786                                     suicide by gas      Song Il-gon
# 434790                                       concert film              NaN
# 434801                                            vampire    Michael Kazlo
#
#                           writers averageRating numVotes  \
# 7       Chuck Palahniuk, Jim Uhls           8.8  2555900
# 95         Jon Lucas, Scott Moore           7.7   915313
# 216                     Alan Ball           8.3  1270120
# 218     Aaron Sorkin, Ben Mezrich           7.8   809374
# 221       Matt Damon, Ben Affleck           8.3  1187897
# ...                           ...           ...      ...
# 434781    Yuri German, Ilya Gurin           6.5       20
# 434784                        NaN           6.1       15
# 434786                Song Il-gon           6.3       76
# 434790                        NaN           6.3        8
# 434801              Michael Kazlo           7.2       18
#
#                                                      cast
# 7       Edward Norton, Brad Pitt, Helena Bonham Carter...
# 95      Bradley Cooper, Ed Helms, Zach Galifianakis, J...
# 216     Kevin Spacey, Annette Bening, Thora Birch, Wes...
# 218     Jesse Eisenberg, Andrew Garfield, Armie Hammer...
# 221     Matt Damon, Robin Williams, Ben Affleck, Stell...
# ...                                                   ...
# 434781  Natalya Tenyakova, Kirill Lavrov, Ivan Lapikov...
# 434784  Aleksandr Borisov, Evgeniy Evstigneev, Viktori...
# 434786                         Son Byung-ho, Choi Ji-yeon
# 434790  Axl Rose, Slash, Izzy Stradlin, Duff McKagan, ...
# 434801  Stefani Brown, Michael J Cannon, Carl Dana, Pi...
#
# [187825 rows x 29 columns]
