# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import nbaide

# %%
nbaide.install()

# %%
df = pd.read_csv("hf://datasets/HenryWaltson/TMDB-IMDB-Movies-Dataset/TMDB  IMDB Movies Dataset.csv")

df.head()
# Out:
# ---nbaide---
# {"type": "dataframe", "shape": [5, 29], "memory_usage_bytes": 10749, "columns": [{"dtype": "int64", "nulls": 0, "stats": {"mean": 45823.8, "std": 63230.09, "min": 155, "max": 157336, "unique": 5}, "name": "id"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Inception", "top_freq": 1}, "name": "title"}, {"dtype": "float64", "nulls": 0, "stats": {"mean": 8.12, "std": 0.44, "min": 7.573, "max": 8.512, "unique": 5}, "name": "vote_average"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 31333.2, "std": 2181.79, "min": 29166, "max": 34495, "unique": 5}, "name": "vote_count"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 1, "top": "Released", "top_freq": 5}, "name": "status"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "2010-07-15", "top_freq": 1}, "name": "release_date"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 1394868391.0, "std": 909620009.18, "min": 701729206, "max": 2923706026, "unique": 5}, "name": "revenue"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 154.8, "std": 10.57, "min": 143, "max": 169, "unique": 5}, "name": "runtime"}, {"dtype": "bool", "nulls": 0, "stats": {"true_count": 0, "true_pct": 0.0}, "name": "adult"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "/8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg", "top_freq": 1}, "name": "backdrop_path"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 193400000.0, "std": 33916072.89, "min": 160000000, "max": 237000000, "unique": 5}, "name": "budget"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "https://www.warnerbros.com/movies/inception", "top_freq": 1}, "name": "homepage"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "tt1375666", "top_freq": 1}, "name": "tconst"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 1, "top": "en", "top_freq": 5}, "name": "original_language"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Inception", "top_freq": 1}, "name": "original_title"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: \"inception\", the implantation of another person's idea into a target's subconscious.", "top_freq": 1}, "name": "overview"}, {"dtype": "float64", "nulls": 0, "stats": {"mean": 106.57, "std": 27.42, "min": 79.932, "max": 140.241, "unique": 5}, "name": "popularity"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "/oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg", "top_freq": 1}, "name": "poster_path"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Your mind is the scene of the crime.", "top_freq": 1}, "name": "tagline"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Action, Science Fiction, Adventure", "top_freq": 1}, "name": "genres"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Legendary Pictures, Syncopy, Warner Bros. Pictures", "top_freq": 1}, "name": "production_companies"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 3, "top": "United Kingdom, United States of America", "top_freq": 3}, "name": "production_countries"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "English, French, Japanese, Swahili", "top_freq": 1}, "name": "spoken_languages"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "rescue, mission, dream, airplane, paris, france, virtual reality, kidnapping, philosophy, spy, allegory, manipulation, car crash, heist, memory, architecture, los angeles, california, dream world, subconscious", "top_freq": 1}, "name": "keywords"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 3, "top": "Christopher Nolan", "top_freq": 3}, "name": "directors"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Christopher Nolan", "top_freq": 1}, "name": "writers"}, {"dtype": "float64", "nulls": 0, "stats": {"mean": 8.5, "std": 0.52, "min": 7.9, "max": 9.1, "unique": 5}, "name": "averag ...
#
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords          directors  \
# 0  rescue, mission, dream, airplane, paris, franc...  Christopher Nolan
# 1  rescue, future, spacecraft, race against time,...  Christopher Nolan
# 2  joker, sadism, chaos, secret identity, crime f...  Christopher Nolan
# 3  future, society, culture clash, space travel, ...      James Cameron
# 4  new york city, superhero, shield, based on com...        Joss Whedon
#
#                                              writers averageRating numVotes  \
# 0                                  Christopher Nolan           8.8  2770171
# 1                  Jonathan Nolan, Christopher Nolan           8.7  2456592
# 2  Jonathan Nolan, Christopher Nolan, David S. Go...           9.1  3116358
# 3                                      James Cameron           7.9  1472421
# 4                              Joss Whedon, Zak Penn           8.0  1539740
#
#                                                 cast
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 1  Matthew McConaughey, Anne Hathaway, Michael Ca...
# 2  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 3  Sam Worthington, Zoe Saldaña, Sigourney Weaver...
# 4  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Exploration du Dataset ##

# %% [markdown]
# The Dataset was found on [HuggingFace](https://huggingface.co/datasets/HenryWaltson/TMDB-IMDB-Movies-Dataset).
# It is composed of TMDB and IMDB movies data.

# %%
print(f"The dataset contains {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# The dataset contains 434803 rows and 29 columns

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 434803 entries, 0 to 434802
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    434803 non-null  int64
#  1   title                 434803 non-null  str
#  2   vote_average          434803 non-null  float64
#  3   vote_count            434803 non-null  int64
#  4   status                434803 non-null  str
#  5   release_date          414261 non-null  str
#  6   revenue               434803 non-null  int64
#  7   runtime               434803 non-null  int64
#  8   adult                 434803 non-null  bool
#  9   backdrop_path         184870 non-null  str
#  10  budget                434803 non-null  int64
#  11  homepage              54526 non-null   str
#  12  tconst                434803 non-null  str
#  13  original_language     434803 non-null  str
#  14  original_title        434803 non-null  str
#  15  overview              392288 non-null  str
#  16  popularity            434803 non-null  float64
#  17  poster_path           359619 non-null  str
#  18  tagline               91750 non-null   str
#  19  genres                355967 non-null  str
#  20  production_companies  261479 non-null  str
#  21  production_countries  320339 non-null  str
#  22  spoken_languages      331531 non-null  str
#  23  keywords              170484 non-null  str
#  24  directors             424832 non-null  str
#  25  writers               369685 non-null  str
#  26  averageRating         434803 non-null  float64
#  27  numVotes              434803 non-null  int64
#  28  cast                  366256 non-null  str
# dtypes: bool(1), float64(3), int64(6), str(19)
# memory usage: 93.3 MB

# %% [markdown]
# ### Nettoyage des données

# %%
df = df.drop_duplicates()

# %%
df = df.drop(columns=['backdrop_path', 'keywords', 'homepage', 'tconst', 'overview', 'poster_path', 'tagline'])

# %%
df = df[df['budget'] != 0]
df = df[df['revenue'] != 0]
df = df[df['release_date'].notna()]

# %% [markdown]
# ### Feature Engineering

# %%
# Feature 1: Rating combiné pondéré
total_votes = df['vote_count'] + df['numVotes']
combined_rating = (df['vote_average'] * df['vote_count'] + df['averageRating'] * df['numVotes']) / total_votes

df['rating'] = combined_rating
df['total_votes'] = total_votes

# %%
df = df.drop(columns=['vote_count', 'numVotes', 'vote_average', 'averageRating'])
df.head()
# Out:
# ---nbaide---
# {"type": "dataframe", "shape": [5, 20], "memory_usage_bytes": 5544, "columns": [{"dtype": "int64", "nulls": 0, "stats": {"mean": 45823.8, "std": 63230.09, "min": 155, "max": 157336, "unique": 5}, "name": "id"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Inception", "top_freq": 1}, "name": "title"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 1, "top": "Released", "top_freq": 5}, "name": "status"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "2010-07-15", "top_freq": 1}, "name": "release_date"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 1394868391.0, "std": 909620009.18, "min": 701729206, "max": 2923706026, "unique": 5}, "name": "revenue"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 154.8, "std": 10.57, "min": 143, "max": 169, "unique": 5}, "name": "runtime"}, {"dtype": "bool", "nulls": 0, "stats": {"true_count": 0, "true_pct": 0.0}, "name": "adult"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 193400000.0, "std": 33916072.89, "min": 160000000, "max": 237000000, "unique": 5}, "name": "budget"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 1, "top": "en", "top_freq": 5}, "name": "original_language"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Inception", "top_freq": 1}, "name": "original_title"}, {"dtype": "float64", "nulls": 0, "stats": {"mean": 106.57, "std": 27.42, "min": 79.932, "max": 140.241, "unique": 5}, "name": "popularity"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Action, Science Fiction, Adventure", "top_freq": 1}, "name": "genres"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Legendary Pictures, Syncopy, Warner Bros. Pictures", "top_freq": 1}, "name": "production_companies"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 3, "top": "United Kingdom, United States of America", "top_freq": 3}, "name": "production_countries"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "English, French, Japanese, Swahili", "top_freq": 1}, "name": "spoken_languages"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 3, "top": "Christopher Nolan", "top_freq": 3}, "name": "directors"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Christopher Nolan", "top_freq": 1}, "name": "writers"}, {"dtype": "str", "nulls": 0, "stats": {"unique": 5, "top": "Leonardo DiCaprio, Joseph Gordon-Levitt, Ken Watanabe, Tom Hardy, Elliot Page, Dileep Rao, Cillian Murphy, Tom Berenger, Marion Cotillard, Pete Postlethwaite", "top_freq": 1}, "name": "cast"}, {"dtype": "float64", "nulls": 0, "stats": {"mean": 8.49, "std": 0.52, "min": 7.893510004420078, "max": 9.094278962953972, "unique": 5}, "name": "rating"}, {"dtype": "int64", "nulls": 0, "stats": {"mean": 2302389.6, "std": 738027.39, "min": 1502236, "max": 3146977, "unique": 5}, "name": "total_votes"}], "sample_rows": [{"id": 27205, "title": "Inception", "status": "Released", "release_date": "2010-07-15", "revenue": 825532764, "runtime": 148, "adult": false, "budget": 160000000, "original_language": "en", "original_title": "Inception", "popularity": 83.952, "genres": "Action, Science Fiction, Adventure", "production_companies": "Legendary Pictures, Syncopy, Warner Bros. Pictures", "production_countries": "United Kingdom, United States of America", "spoken_languages": "English, French, Japanese, Swahili", "directors": "Christopher Nolan", "writers": "Christopher Nolan", "cast": "Leonardo DiCaprio, Joseph Gordon-Levitt, Ken Watanabe, Tom Hardy, Elliot Page, Dileep Rao, Cillian Murphy, Tom Berenger, Marion Cotillard, Pete Postlethwaite", "rating": 8.794637571817821, "total_votes": 2804666}, {"id": 157336, "title": "Interstellar", "status": "Released", "release_date": "2014-11-05", "revenue": 701729206, "runtime": 169, "adult": false, "budget": 165000000, "original_language": "en", "original_title": "Interstellar", "popularity": 140.241, "genres": "Adventure, Drama, Science Fiction", "production_companies": "Legendary Pictures, Syncopy, Lynda Obst Productions", "production_c ...
#
#        id            title    status release_date     revenue  runtime  adult  \
# 0   27205        Inception  Released   2010-07-15   825532764      148  False
# 1  157336     Interstellar  Released   2014-11-05   701729206      169  False
# 2     155  The Dark Knight  Released   2008-07-16  1004558444      152  False
# 3   19995           Avatar  Released   2009-12-15  2923706026      162  False
# 4   24428     The Avengers  Released   2012-04-25  1518815515      143  False
#
#       budget original_language   original_title  popularity  \
# 0  160000000                en        Inception      83.952
# 1  165000000                en     Interstellar     140.241
# 2  185000000                en  The Dark Knight     130.643
# 3  237000000                en           Avatar      79.932
# 4  220000000                en     The Avengers      98.082
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages          directors  \
# 0  English, French, Japanese, Swahili  Christopher Nolan
# 1                             English  Christopher Nolan
# 2                   English, Mandarin  Christopher Nolan
# 3                    English, Spanish      James Cameron
# 4             English, Hindi, Russian        Joss Whedon
#
#                                              writers  \
# 0                                  Christopher Nolan
# 1                  Jonathan Nolan, Christopher Nolan
# 2  Jonathan Nolan, Christopher Nolan, David S. Go...
# 3                                      James Cameron
# 4                              Joss Whedon, Zak Penn
#
#                                                 cast    rating  total_votes
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...  8.794638      2804666
# 1  Matthew McConaughey, Anne Hathaway, Michael Ca...  8.696297      2489163
# 2  Christian Bale, Heath Ledger, Aaron Eckhart, M...  9.094279      3146977
# 3  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  7.893510      1502236
# 4  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...  7.994609      1568906

# %%
df['release_year'] = pd.to_datetime(df['release_date']).dt.year

# %%
features = [
    'rating',     # Rating pondéré TMDB+IMDB (créé)
    'total_votes',         # vote_count + numVotes (créé)
    'popularity',          # Score TMDB de buzz actuel
    'runtime',      
    'release_year',
    'budget',
    'revenue'
]

# %% [markdown]
# ### Focus on the Label : Genres

# %%
unique_genres = df['genres'].dropna().str.split(', ').explode().unique()
number_of_genre = len(unique_genres)

print(f"There is {number_of_genre} different genres, that are :", sorted(unique_genres))
# Out:
# There is 19 different genres, that are : ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction', 'TV Movie', 'Thriller', 'War', 'Western']

# %%
single_genre_count = df[df['genres'].str.contains(',', na=True) == False].shape[0]
print(f"Number of rows with only one unique genre: {single_genre_count}")
# Out:
# Number of rows with only one unique genre: 1812

# %% [markdown]
# On va donc prendre les films avec plusieurs genres, mais en gardant le premier genre qui apprait

# %%
# Supprimer les films sans genre
df_clean = df[df['genres'].notna()].copy()
print(f"Films avec genres : {len(df_clean)} / {len(df)}")

# Extraire le premier genre
df_clean['genre'] = df_clean['genres'].str.split(',').str[0].str.strip()

# Distribution des genres
print("\n Distribution des genres :")
genre_counts = df_clean['genre'].value_counts()
print(genre_counts.head(20))

print(f"\n Total de genres uniques : {df_clean['genre'].nunique()}")
# Out:
# Films avec genres : 10098 / 10182
#
#  Distribution des genres :
# genre
# Drama              2410
# Comedy             2180
# Action             1467
# Horror              674
# Adventure           576
# Crime               454
# Thriller            441
# Animation           328
# Romance             307
# Science Fiction     229
# Fantasy             216
# Family              203
# Documentary         138
# Mystery             127
# Music               108
# War                 100
# Western              73
# History              65
# TV Movie              2
# Name: count, dtype: int64
#
#  Total de genres uniques : 19

# %%
# Garder Top 5 genres
top_5_genres = df_clean['genre'].value_counts().head(5).index.tolist()
df_final = df_clean[df_clean['genre'].isin(top_5_genres)].copy()

print(f"Films gardés : {len(df_final)}")
print(f"Genres : {top_5_genres}")
print("\n Distribution finale :")
print(df_final['genre'].value_counts())
# Out:
# Films gardés : 7307
# Genres : ['Drama', 'Comedy', 'Action', 'Horror', 'Adventure']
#
#  Distribution finale :
# genre
# Drama        2410
# Comedy       2180
# Action       1467
# Horror        674
# Adventure     576
# Name: count, dtype: int64

# %% [markdown]
# ### Rééquilibrage des classes (Undersampling)

# %%
# Undersampling : on plafonne chaque classe au niveau de la plus petite (Adventure = 576)
cap = df_final['genre'].value_counts().min()
print(f"Cap par classe : {cap}")

df_balanced = (
    df_final
    .groupby('genre', group_keys=False)
    .sample(n=cap, random_state=42)
)

print("\nDistribution après rééquilibrage :")
print(df_balanced['genre'].value_counts())
print(f"\nTotal : {len(df_balanced)} films")
# Out:
# Cap par classe : 576
#
# Distribution après rééquilibrage :
# genre
# Action       576
# Adventure    576
# Comedy       576
# Drama        576
# Horror       576
# Name: count, dtype: int64
#
# Total : 2880 films

# %%
X = df_balanced[features]
y = df_balanced['genre']

# %%
# 1. Train/test split stratifié
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.2,
    stratify=y,
    random_state=42
)

# 2. Scaling avec RobustScaler
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 3. Entraînement
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
model = GaussianNB()
model.fit(X_train_scaled, y_train)

# 4. Évaluation
y_pred = model.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Action       0.33      0.03      0.05       115
#    Adventure       0.43      0.30      0.36       115
#       Comedy       0.22      0.52      0.31       115
#        Drama       0.36      0.60      0.45       116
#       Horror       0.36      0.07      0.12       115
#
#     accuracy                           0.31       576
#    macro avg       0.34      0.31      0.26       576
# weighted avg       0.34      0.31      0.26       576

# %%
# Paramètres du modèle GaussianNB
print("=" * 60)
print("PARAMÈTRES DU MODÈLE GAUSSIEN NAIVE BAYES")
print("=" * 60)

# 1. Probabilités a priori des classes P(classe)
print("\n1. PROBABILITÉS A PRIORI P(classe):")
print("-" * 40)
for classe, proba in zip(model.classes_, model.class_prior_):
    print(f"   {classe:12s}: {proba:.4f} ({proba*100:.2f}%)")

# 2. Moyennes (theta) par feature et par classe
print("\n2. MOYENNES (μ) PAR FEATURE ET CLASSE:")
print("-" * 40)
theta_df = pd.DataFrame(
    model.theta_, 
    index=model.classes_, 
    columns=features
)
print(theta_df.round(3))

# 3. Variances par feature et par classe
print("\n3. VARIANCES (σ²) PAR FEATURE ET CLASSE:")
print("-" * 40)
var_df = pd.DataFrame(
    model.var_, 
    index=model.classes_, 
    columns=features
)
print(var_df.round(3))
# Out:
# ============================================================
# PARAMÈTRES DU MODÈLE GAUSSIEN NAIVE BAYES
# ============================================================
#
# 1. PROBABILITÉS A PRIORI P(classe):
# ----------------------------------------
#    Action      : 0.2001 (20.01%)
#    Adventure   : 0.2001 (20.01%)
#    Comedy      : 0.2001 (20.01%)
#    Drama       : 0.1997 (19.97%)
#    Horror      : 0.2001 (20.01%)
#
# 2. MOYENNES (μ) PAR FEATURE ET CLASSE:
# ----------------------------------------
#            rating  total_votes  popularity  runtime  release_year  budget  \
# Action     -0.188        0.832       1.743    0.361        -0.078   0.956
# Adventure   0.005        1.452       0.702    0.328        -0.470   1.435
# Comedy     -0.133        0.357      -0.001   -0.075        -0.275   0.211
# Drama       0.257        0.532      -0.072    0.397        -0.354   0.150
# Horror     -0.384        0.455       0.777   -0.273        -0.186   0.010
#
#            revenue
# Action       1.079
# Adventure    2.400
# Comedy       0.488
# Drama        0.267
# Horror       0.347
#
# 3. VARIANCES (σ²) PAR FEATURE ET CLASSE:
# ----------------------------------------
#            rating  total_votes  popularity  runtime  release_year  budget  \
# Action      0.696        4.380     190.586    1.070         0.547   3.161
# Adventure   0.571        9.280       3.502    1.216         1.035   4.950
# Comedy      0.514        1.373       2.044    0.609         0.816   0.480
# Drama       0.389        3.998       0.472    1.283         1.177   0.493
# Horror      0.576        1.379      30.423    3.201         0.690   0.354
#
#            revenue
# Action       5.604
# Adventure   22.913
# Comedy       1.662
# Drama        0.948
# Horror       0.844

# %% [markdown]
# ## Étape 5 — Évaluation complète des performances

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=model.classes_, yticklabels=model.classes_, ax=ax)
ax.set_xlabel("Prédit")
ax.set_ylabel("Réel")
ax.set_title("Matrice de confusion — GaussianNB")
plt.tight_layout()
plt.show()
# Out:
# ---nbaide---
# {"type": "figure", "size_inches": [8.0, 6.0], "axes": [{"title": "Matrice de confusion \u2014 GaussianNB", "xlabel": "Pr\u00e9dit", "ylabel": "R\u00e9el", "xlim": [0.0, 5.0], "ylim": [5.0, 0.0], "series": [{"plot_type": "heatmap", "cmap": "Blues", "shape": [5, 5], "data": [[3.0, 22.0, 56.0, 30.0, 4.0], [2.0, 35.0, 47.0, 29.0, 2.0], [0.0, 7.0, 60.0, 45.0, 3.0], [0.0, 10.0, 31.0, 70.0, 5.0], [4.0, 7.0, 76.0, 20.0, 8.0]]}]}, {"xlim": [0.0, 1.0], "ylim": [0.0, 76.0], "series": [{"plot_type": "heatmap", "cmap": "Blues", "shape": [256, 1], "stats": {"min": 0.15, "max": 75.85, "mean": 38.0, "std": 21.94}}]}]}

# %% [markdown]
# ## Étape 6 — Analyse des résultats
#
# ### Ce que le modèle fait bien
# - **Drama** (F1 = 0.56) et **Comedy** (F1 = 0.45) sont les mieux prédits, ce qui est cohérent avec leur surreprésentation dans les données (respectivement 33% et 30% du dataset).
# - Le modèle apprend les priors de classe : il prédit surtout Drama et Comedy car ce sont les genres dominants.
#
# ### Ce que le modèle rate
# - **Horror** (F1 = 0.04) et **Action** (F1 = 0.12) sont quasi ignorés : le modèle les classe massivement en Drama/Comedy.
# - **Adventure** (F1 = 0.25) s'en sort un peu mieux grâce à des features distinctives (budget et revenue élevés).
#
# ### Pourquoi ces résultats sont faibles (accuracy = 42%)
#
# 1. **Les features choisies ne discriminent pas bien les genres.** Le `rating`, `popularity`, `runtime`, etc. ne sont pas vraiment des indicateurs de genre — un Drama peut avoir autant de votes qu'un Action.
#
# 2. **Hypothèse d'indépendance de Naive Bayes est violée.** `budget` et `revenue` sont très corrélés, `rating` et `total_votes` aussi.
#
# 3. **Déséquilibre des classes.** Drama + Comedy = 63% des données, ce qui biaise les prédictions vers ces genres.
#
# 4. **Les features numériques seules sont insuffisantes** pour distinguer des genres qui sont des constructions sémantiques (le texte du synopsis ou des mots-clés seraient bien plus discriminants).
#
# ### Pistes d'amélioration à explorer
# - Rééquilibrage des classes (oversampling, class_weight)
# - Ajout de features textuelles (TF-IDF sur le synopsis/titre) → `MultinomialNB` ou `ComplementNB`
# - Réduction du nombre de genres cibles
# - Comparaison avec d'autres classifieurs (LogisticRegression, RandomForest)
